# %%
import os, gc, time
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl
username = os.getenv('USER')
import dask.array as da
from dask_jobqueue import SLURMCluster
from dask.distributed import Client, progress
import dask
from collections import OrderedDict
dask.config.set(**{'array.slicing.split_large_chunks': False})
# dask.config.set({"distributed.workers.memory.target": 4})

from dscim import ProWaiter
from dscim.menu.simple_storage import StackedDamages, EconVars, Climate
from dscim.menu.risk_aversion import RiskAversionRecipe
from dscim.menu.baseline import Baseline
from dscim.menu.equity import EquityRecipe
from itertools import product, chain
import itertools
# import seaborn as sns
from dscim.fair.utils import modeler
from dscim.fair.estimations import c_equivalence
from functools import reduce
from pathlib import Path

import seaborn as sns
from dscim.fair.estimations import compute_damages

# %%
discount_types = ["euler_ramsey"]#, "euler_gwr","euler_ramsey", "naive_gwr", "naive_ramsey"]
menu_options = ["risk_aversion", "adding_up", "equity"]
pulse_years = [2020]
# pulse_years = list(range(2025, 2051, 5))
weitzman_values = [x / 10.0 for x in range(1, 11, 1)] + [0.25, 0.01, 0.001, 0.0001]
global_cons = True
factors = False
marginal_damages = False
masks = ["unmasked",
        #  "truncate_at_ecs995symmetric_passing_mask",
        # "truncate_at_ecs990symmetric_passing_mask",
        # "truncate_at_ecs950symmetric_passing_mask",
        # "truncate_at_ecs830symmetric_passing_mask",
        # "truncate_at_ecs750symmetric_passing_mask",
        ]

fair_dims_list= [
    ['simulation'],
    ['simulation', 'ssp', 'model'],
    ['simulation', 'rcp', 'model'],
    ['simulation', 'ssp', 'model', 'rcp'],
]

# %% [markdown]
# # run all

# %%
sectors = ["integration_CAMEL_clipped_ag1090"] # , "integration_AMEL_clipped", "coastal"]
AR_list = [6] # 5
combos = [(s, p, d, m, ar, ma, f) 
          for p in pulse_years
          for s in sectors 
          for d in discount_types 
          for m in menu_options
          for ar in AR_list
          for ma in masks
          for f in fair_dims_list
         ]

# %%
n_combos = len(combos)

while n_combos > 0: 
    combo = combos[0]
    print("=========================================================")
    print(combo)
    sector = combo[0]
    pulse_year = combo[1]
    discount_type = combo[2]
    menu_option = combo[3]
    AR = combo[4]
    mask = combo[5]
    fair_dims = combo[6]

    if len(fair_dims) > 1:
        print(fair_dims)
        fair_folder = f"fair_collapsed_{'_'.join([i for i in fair_dims if i!='simulation'])}"
    else:
        fair_folder = ''

    w = ProWaiter(path_to_config=f'/home/{username}/repos/integration/configs/epa_tool_config-histclim_AR{AR}.yaml')
    save_path=f'/mnt/CIL_integration/menu_results_AR{AR}_bc39_integration/{sector}/{pulse_year}/{mask}/{fair_folder}'

    if mask=='unmasked':
        mask = None

    kwargs = {'discounting_type' : discount_type,
              'sector': sector,
              'ce_path' : f'/shares/gcp/integration/CE_library_epa_vsl_bc39/{sector}/',
              'save_path' : save_path,
              'fair_dims' : fair_dims,
              'weitzman_parameter' : weitzman_values,
              'pulse_year' : pulse_year,
              'ecs_mask_name' : mask,
              'eta' : 2.0,
              'rho' : 0.0,
             }

    if "CAMEL" in sector:
        kwargs.update({
            'damage_function_path' : f'/mnt/CIL_integration/damage_function_library/damage_function_library_integration/{sector}'
        })

    menu_item = w.menu_factory(menu_key=menu_option,
                                           sector=sector,
                                           kwargs=kwargs
                                          )
    menu_item.order_plate('scc')
    if "CAMEL" not in sector:
        menu_item.damage_function_fit
        
    # menu_item.order_plate('scc')
        
    if global_cons == True:
        menu_item.global_consumption_no_pulse.to_netcdf(
            f"{save_path}/{menu_option}_{discount_type}_eta{menu_item.eta}_rho{menu_item.rho}_global_consumption_no_pulse.nc4")
        menu_item.global_consumption.to_netcdf(
            f"{save_path}/{menu_option}_{discount_type}_eta{menu_item.eta}_rho{menu_item.rho}_global_consumption.nc4")

    if marginal_damages==True:
        md = (menu_item.global_consumption_no_pulse - menu_item.global_consumption_pulse) * menu_item.climate.conversion
        md = md.rename('marginal_damages').to_dataset()
        for var in md.variables:
            md[var].encoding.clear()
        md.chunk({
            "discount_type":1,
             "weitzman_parameter":1,
             "ssp":1,
             "model":1,
             "gas":1,
             "year":10
        }).to_zarr(
            f'{save_path}/{menu_option}_{discount_type}_eta{menu_item.eta}_rho{menu_item.rho}_uncollapsed_marginal_damages.zarr',
            consolidated = True,
            mode = "w"
        )

    if factors==True:
        
        # holding population constant
        # from 2100 to 2300 with 2099 values
        pop = menu_item.collapsed_pop.sum("region")
        pop = pop.reindex(
            year=range(pop.year.min().values, menu_item.ext_end_year + 1), method="ffill"
        )
        
        df = menu_item.calculate_discount_factors(
            menu_item.global_consumption_no_pulse / pop
        ).to_dataset(name = "discount_factor")
        for var in df.variables:
            df[var].encoding.clear()
        df.chunk({
            "discount_type":1,
             "weitzman_parameter":1,
             "ssp":1,
             "model":1,
             "gas":1,
             "year":10
        }).to_zarr(
            f'{save_path}/{menu_option}_{discount_type}_eta{menu_item.eta}_rho{menu_item.rho}_uncollapsed_discount_factors.zarr',
            consolidated = True,
            mode = "w"
        )

    combos.remove(combo)
    n_combos = len(combos)
    print(f"remaining combos: {n_combos}")
# Out:
# =========================================================
# ('integration_AMEL_clipped_ag1090', 2020, 'constant', 'risk_aversion', 6, 'unmasked', ['simulation'])
#
#  Executing Running risk_aversion class with the following parameters:
# Sector: integration_AMEL_clipped_ag1090
# Discount type: constant
# Damage function path: None
#
#
# Processing damage functions ...
# Existing damage functions not found. Damage points will be loaded.
# Risk-aversion CEs found at /shares/gcp/integration/CE_library_epa_vsl_bc39/integration_AMEL_clipped_ag1090//risk_aversion_ce_no_cc_eta2.0.zarr. These are being loaded...
# Risk-aversion CEs found at /shares/gcp/integration/CE_library_epa_vsl_bc39/integration_AMEL_clipped_ag1090//risk_aversion_ce_cc_eta2.0.zarr. These are being loaded...
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_AMEL_clipped_ag1090/2020/unmasked/risk_aversion_constant_eta2.0_rho0.0_damage_function_points.csv
# Extrapolating global consumption.
# End-of-century growth rates are not capped.
# Skipped saving global_consumption.
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_AMEL_clipped_ag1090/2020/unmasked/risk_aversion_constant_eta2.0_rho0.0_damage_function_coefficients.nc4
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_AMEL_clipped_ag1090/2020/unmasked/risk_aversion_constant_eta2.0_rho0.0_damage_function_fit.nc4
# Processing SCC calculation ...
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_AMEL_clipped_ag1090/2020/unmasked/risk_aversion_constant_eta2.0_rho0.0_damage_function_coefficients.nc4
# Skipped saving ce_fair_no_pulse.
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_AMEL_clipped_ag1090/2020/unmasked/risk_aversion_constant_eta2.0_rho0.0_damage_function_coefficients.nc4
# Skipped saving ce_fair_pulse.
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_AMEL_clipped_ag1090/2020/unmasked/risk_aversion_constant_eta2.0_rho0.0_damage_function_coefficients.nc4
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_AMEL_clipped_ag1090/2020/unmasked/risk_aversion_constant_eta2.0_rho0.0_damage_function_coefficients.nc4
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_AMEL_clipped_ag1090/2020/unmasked/risk_aversion_constant_eta2.0_rho0.0_marginal_damages.nc4
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_AMEL_clipped_ag1090/2020/unmasked/risk_aversion_constant_eta2.0_rho0.0_uncollapsed_sccs.nc4
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py:4458: PerformanceWarning: Increasing number of chunks by factor of 14
#   result = blockwise(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_243195/4283458616.py in <module>
#      46                                            kwargs=kwargs
#      47                                           )
# ---> 48     menu_item.order_plate('scc')
#      49     if "CAMEL" not in sector:
#      50         menu_item.damage_function_fit
#
# ~/repos/integration/dscim/menu/main_recipe.py in order_plate(self, course)
#     381
#     382         try:
# --> 383             course_dict[course]()
#     384             self.logger.info(f"Results available: {self.save_path}")
#     385         except KeyError as e:
#
# ~/repos/integration/dscim/menu/main_recipe.py in scc()
#     375                 if len(self.fair_aggregation) > 0:
#     376                     self.stream_discount_factors
# --> 377                     self.calculate_scc
#     378                 self.uncollapsed_sccs
#     379
#
# ~/repos/integration/dscim/descriptors.py in __get__(self, instance, _type)
#      16             return self
#      17
# ---> 18         setattr(instance, self.__func__.__name__, self.__func__(instance))
#      19
#      20         # This descriptor is now overridden for this instance:
#
# ~/repos/integration/dscim/menu/decorators.py in save_wrap(self, *args, **kwargs)
#      24         @functools.wraps(func)
#      25         def save_wrap(self, *args, **kwargs):
# ---> 26             out = func(self, *args, **kwargs)
#      27             save = out
#      28
#
# ~/repos/integration/dscim/menu/main_recipe.py in calculate_scc(self)
#    1154             median = self.uncollapsed_sccs.median(self.fair_dims)
#    1155             median["fair_aggregation"] = ["median"]
# -> 1156             discounted_damages = xr.merge([median.rename("scc"), discounted_damages])
#    1157
#    1158         return discounted_damages
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/merge.py in merge(objects, compat, join, fill_value, combine_attrs)
#     903         dict_like_objects.append(obj)
#     904
# --> 905     merge_result = merge_core(
#     906         dict_like_objects,
#     907         compat,
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/merge.py in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     638
#     639     prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
# --> 640     variables, out_indexes = merge_collected(
#     641         collected, prioritized, compat=compat, combine_attrs=combine_attrs
#     642     )
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/merge.py in merge_collected(grouped, prioritized, compat, combine_attrs)
#     240                 variables = [variable for variable, _ in elements_list]
#     241                 try:
# --> 242                     merged_vars[name] = unique_variable(name, variables, compat)
#     243                 except MergeError:
#     244                     if compat != "minimal":
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/merge.py in unique_variable(name, variables, compat, equals)
#     142         if equals is None:
#     143             # now compare values with minimum number of computes
# --> 144             out = out.compute()
#     145             for var in variables[1:]:
#     146                 equals = getattr(out, compat)(var)
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py in compute(self, **kwargs)
#     473         """
#     474         new = self.copy(deep=False)
# --> 475         return new.load(**kwargs)
#     476
#     477     def __dask_tokenize__(self):
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py in load(self, **kwargs)
#     449         """
#     450         if is_duck_dask_array(self._data):
# --> 451             self._data = as_compatible_data(self._data.compute(**kwargs))
#     452         elif not is_duck_array(self._data):
#     453             self._data = np.asarray(self._data)
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     286         dask.base.compute
#     287         """
# --> 288         (result,) = compute(self, traverse=False, **kwargs)
#     289         return result
#     290
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     568         postcomputes.append(x.__dask_postcompute__())
#     569
# --> 570     results = schedule(dsk, keys, **kwargs)
#     571     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     572
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      77             pool = MultiprocessingPoolExecutor(pool)
#      78
# ---> 79     results = get_async(
#      80         pool.submit,
#      81         pool._max_workers,
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     494             while state["waiting"] or state["ready"] or state["running"]:
#     495                 fire_tasks(chunksize)
# --> 496                 for key, res_info, failed in queue_get(queue).result():
#     497                     if failed:
#     498                         exc, tb = loads(res_info)
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py in queue_get(q)
#     132
#     133     def queue_get(q):
# --> 134         return q.get()
#     135
#     136
#
# ~/miniconda3/envs/dscim/lib/python3.8/queue.py in get(self, block, timeout)
#     180             item = self._get()
#     181             self.not_full.notify()
# --> 182             return item
#     183
#     184     def put_nowait(self, item):
#
# KeyboardInterrupt:
