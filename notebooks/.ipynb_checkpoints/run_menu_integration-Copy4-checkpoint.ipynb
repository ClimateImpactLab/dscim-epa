# %%
import os, gc, time
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl
username = os.getenv('USER')
import dask.array as da
from dask_jobqueue import SLURMCluster
from dask.distributed import Client, progress
import dask
from collections import OrderedDict
dask.config.set(**{'array.slicing.split_large_chunks': False})
# dask.config.set({"distributed.workers.memory.target": 4})

from dscim import ProWaiter
from dscim.menu.simple_storage import StackedDamages, EconVars, Climate
from dscim.menu.risk_aversion import RiskAversionRecipe
from dscim.menu.baseline import Baseline
from dscim.menu.equity import EquityRecipe
from itertools import product, chain
import itertools
# import seaborn as sns
from dscim.fair.utils import modeler
from dscim.fair.estimations import c_equivalence
from functools import reduce
from pathlib import Path

import seaborn as sns
from dscim.fair.estimations import compute_damages
# Out:
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask_jobqueue/core.py:17: FutureWarning: format_bytes is deprecated and will be removed in a future release. Please use dask.utils.format_bytes instead.
#   from distributed.utils import format_bytes, parse_bytes, tmpfile, get_ip_interface
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask_jobqueue/core.py:17: FutureWarning: parse_bytes is deprecated and will be removed in a future release. Please use dask.utils.parse_bytes instead.
#   from distributed.utils import format_bytes, parse_bytes, tmpfile, get_ip_interface
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask_jobqueue/core.py:17: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import format_bytes, parse_bytes, tmpfile, get_ip_interface
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask_jobqueue/htcondor.py:6: FutureWarning: parse_bytes is deprecated and will be removed in a future release. Please use dask.utils.parse_bytes instead.
#   from distributed.utils import parse_bytes

# %%
discount_types = ["naive_ramsey"]#, "euler_gwr","euler_ramsey", "naive_gwr", "naive_ramsey"]
menu_options = ["risk_aversion", "adding_up", "equity"]
pulse_years = [2020]
# pulse_years = list(range(2025, 2051, 5))
weitzman_values = [x / 10.0 for x in range(1, 11, 1)] + [0.25, 0.01, 0.001, 0.0001]
global_cons = True
factors = False
marginal_damages = False
masks = ["unmasked",
        #  "truncate_at_ecs995symmetric_passing_mask",
        # "truncate_at_ecs990symmetric_passing_mask",
        # "truncate_at_ecs950symmetric_passing_mask",
        # "truncate_at_ecs830symmetric_passing_mask",
        # "truncate_at_ecs750symmetric_passing_mask",
        ]

fair_dims_list= [
    ['simulation'],
    ['simulation', 'ssp', 'model'],
    ['simulation', 'rcp', 'model'],
    ['simulation', 'ssp', 'model', 'rcp'],
]

# %% [markdown]
# # run all

# %%
sectors = ["integration_CAMEL_clipped_ag1090"] # , "integration_AMEL_clipped", "coastal"]
AR_list = [6] # 5
combos = [(s, p, d, m, ar, ma, f) 
          for p in pulse_years
          for s in sectors 
          for d in discount_types 
          for m in menu_options
          for ar in AR_list
          for ma in masks
          for f in fair_dims_list
         ]

# %%
n_combos = len(combos)

while n_combos > 0: 
    combo = combos[0]
    print("=========================================================")
    print(combo)
    sector = combo[0]
    pulse_year = combo[1]
    discount_type = combo[2]
    menu_option = combo[3]
    AR = combo[4]
    mask = combo[5]
    fair_dims = combo[6]

    if len(fair_dims) > 1:
        print(fair_dims)
        fair_folder = f"fair_collapsed_{'_'.join([i for i in fair_dims if i!='simulation'])}"
    else:
        fair_folder = ''

    w = ProWaiter(path_to_config=f'/home/{username}/repos/integration/configs/epa_tool_config-histclim_AR{AR}.yaml')
    save_path=f'/mnt/CIL_integration/menu_results_AR{AR}_bc39_integration/{sector}/{pulse_year}/{mask}/{fair_folder}'

    if mask=='unmasked':
        mask = None

    kwargs = {'discounting_type' : discount_type,
              'sector': sector,
              'ce_path' : f'/shares/gcp/integration/CE_library_epa_vsl_bc39/{sector}/',
              'save_path' : save_path,
              'fair_dims' : fair_dims,
              'weitzman_parameter' : weitzman_values,
              'pulse_year' : pulse_year,
              'ecs_mask_name' : mask,
              'eta' : 2.0,
              'rho' : 0.0,
             }

    if "CAMEL" in sector:
        kwargs.update({
            'damage_function_path' : f'/mnt/CIL_integration/damage_function_library/damage_function_library_integration/{sector}'
        })

    menu_item = w.menu_factory(menu_key=menu_option,
                                           sector=sector,
                                           kwargs=kwargs
                                          )
    menu_item.order_plate('scc')
    if "CAMEL" not in sector:
        menu_item.damage_function_fit
        
    # menu_item.order_plate('scc')
        
    if global_cons == True:
        menu_item.global_consumption_no_pulse.to_netcdf(
            f"{save_path}/{menu_option}_{discount_type}_eta{menu_item.eta}_rho{menu_item.rho}_global_consumption_no_pulse.nc4")
        menu_item.global_consumption.to_netcdf(
            f"{save_path}/{menu_option}_{discount_type}_eta{menu_item.eta}_rho{menu_item.rho}_global_consumption.nc4")

    if marginal_damages==True:
        md = (menu_item.global_consumption_no_pulse - menu_item.global_consumption_pulse) * menu_item.climate.conversion
        md = md.rename('marginal_damages').to_dataset()
        for var in md.variables:
            md[var].encoding.clear()
        md.chunk({
            "discount_type":1,
             "weitzman_parameter":1,
             "ssp":1,
             "model":1,
             "gas":1,
             "year":10
        }).to_zarr(
            f'{save_path}/{menu_option}_{discount_type}_eta{menu_item.eta}_rho{menu_item.rho}_uncollapsed_marginal_damages.zarr',
            consolidated = True,
            mode = "w"
        )

    if factors==True:
        
        # holding population constant
        # from 2100 to 2300 with 2099 values
        pop = menu_item.collapsed_pop.sum("region")
        pop = pop.reindex(
            year=range(pop.year.min().values, menu_item.ext_end_year + 1), method="ffill"
        )
        
        df = menu_item.calculate_discount_factors(
            menu_item.global_consumption_no_pulse / pop
        ).to_dataset(name = "discount_factor")
        for var in df.variables:
            df[var].encoding.clear()
        df.chunk({
            "discount_type":1,
             "weitzman_parameter":1,
             "ssp":1,
             "model":1,
             "gas":1,
             "year":10
        }).to_zarr(
            f'{save_path}/{menu_option}_{discount_type}_eta{menu_item.eta}_rho{menu_item.rho}_uncollapsed_discount_factors.zarr',
            consolidated = True,
            mode = "w"
        )

    combos.remove(combo)
    n_combos = len(combos)
    print(f"remaining combos: {n_combos}")
# Out:
# =========================================================
# ('integration_CAMEL_clipped_ag1090', 2020, 'naive_ramsey', 'risk_aversion', 6, 'unmasked', ['simulation'])
#
#  Executing Running risk_aversion class with the following parameters:
# Sector: integration_CAMEL_clipped_ag1090
# Discount type: naive_ramsey
# Damage function path: /mnt/CIL_integration/damage_function_library/damage_function_library_integration/integration_CAMEL_clipped_ag1090
#
#
# Processing damage functions ...
# You have passed a path to damage functions. Loading damage function coefficients...
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_CAMEL_clipped_ag1090/2020/unmasked/risk_aversion_naive_ramsey_eta2.0_rho0.0_damage_function_coefficients.nc4
# You have passed a path to damage functions. Loading fitted damage functions...
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_CAMEL_clipped_ag1090/2020/unmasked/risk_aversion_naive_ramsey_eta2.0_rho0.0_damage_function_fit.nc4
# Extrapolating global consumption.
# End-of-century growth rates are not capped.
# Skipped saving global_consumption.
# Processing SCC calculation ...
# End-of-century growth rates are not capped.
# continuous discounting
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_CAMEL_clipped_ag1090/2020/unmasked/risk_aversion_naive_ramsey_eta2.0_rho0.0_discount_factors.nc4
# /home/liruixue/repos/integration/dscim/menu/main_recipe.py:1280: FutureWarning: xarray.ufuncs is deprecated. Instead, use numpy ufuncs directly.
#   rhos = xr.ufuncs.expm1(xr.DataArray(self.rho, coords=[cons_pc.year]))
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataarray.py:3061: FutureWarning: xarray.ufuncs is deprecated. Instead, use numpy ufuncs directly.
#   da = self.__array_wrap__(f(self.variable.data, *args, **kwargs))
# You have passed a path to damage functions. Loading damage function coefficients...
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_CAMEL_clipped_ag1090/2020/unmasked/risk_aversion_naive_ramsey_eta2.0_rho0.0_damage_function_coefficients.nc4
# Skipped saving ce_fair_no_pulse.
# You have passed a path to damage functions. Loading damage function coefficients...
# Saving /mnt/CIL_integration/menu_results_AR6_bc39_integration/integration_CAMEL_clipped_ag1090/2020/unmasked/risk_aversion_naive_ramsey_eta2.0_rho0.0_damage_function_coefficients.nc4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_243574/4283458616.py in <module>
#      46                                            kwargs=kwargs
#      47                                           )
# ---> 48     menu_item.order_plate('scc')
#      49     if "CAMEL" not in sector:
#      50         menu_item.damage_function_fit
#
# ~/repos/integration/dscim/menu/main_recipe.py in order_plate(self, course)
#     381
#     382         try:
# --> 383             course_dict[course]()
#     384             self.logger.info(f"Results available: {self.save_path}")
#     385         except KeyError as e:
#
# ~/repos/integration/dscim/menu/main_recipe.py in scc()
#     375                 if len(self.fair_aggregation) > 0:
#     376                     self.stream_discount_factors
# --> 377                     self.calculate_scc
#     378                 self.uncollapsed_sccs
#     379
#
# ~/repos/integration/dscim/descriptors.py in __get__(self, instance, _type)
#      16             return self
#      17
# ---> 18         setattr(instance, self.__func__.__name__, self.__func__(instance))
#      19
#      20         # This descriptor is now overridden for this instance:
#
# ~/repos/integration/dscim/menu/decorators.py in save_wrap(self, *args, **kwargs)
#      24         @functools.wraps(func)
#      25         def save_wrap(self, *args, **kwargs):
# ---> 26             out = func(self, *args, **kwargs)
#      27             save = out
#      28
#
# ~/repos/integration/dscim/menu/main_recipe.py in calculate_scc(self)
#    1147
#    1148         discounted_damages = self.discounted_damages(
# -> 1149             damages=self.marginal_damages, discrate=self.discounting_type
#    1150         )
#    1151         discounted_damages = discounted_damages.sum(dim="year").rename("scc")
#
# ~/repos/integration/dscim/descriptors.py in __get__(self, instance, _type)
#      16             return self
#      17
# ---> 18         setattr(instance, self.__func__.__name__, self.__func__(instance))
#      19
#      20         # This descriptor is now overridden for this instance:
#
# ~/repos/integration/dscim/menu/decorators.py in save_wrap(self, *args, **kwargs)
#      24         @functools.wraps(func)
#      25         def save_wrap(self, *args, **kwargs):
# ---> 26             out = func(self, *args, **kwargs)
#      27             save = out
#      28
#
# ~/repos/integration/dscim/menu/main_recipe.py in marginal_damages(self)
#    1116
#    1117             if agg == "ce":
# -> 1118                 md = self.ce_fair_no_pulse - self.ce_fair_pulse
#    1119             elif agg in ["mean", "gwr_mean"]:
#    1120                 md = self.global_consumption_no_pulse.mean(
#
# ~/repos/integration/dscim/menu/decorators.py in save_wrap(self, *args, **kwargs)
#      24         @functools.wraps(func)
#      25         def save_wrap(self, *args, **kwargs):
# ---> 26             out = func(self, *args, **kwargs)
#      27             save = out
#      28
#
# ~/repos/integration/dscim/menu/main_recipe.py in ce_fair_pulse(self)
#    1093     def ce_fair_pulse(self):
#    1094         """Certainty equivalent of global consumption under FAIR pulse scenario"""
# -> 1095         ce_array = self.ce(self.global_consumption_pulse, dims=self.fair_dims)
#    1096
#    1097         return ce_array.rename("ce_fair_pulse")
#
# ~/repos/integration/dscim/descriptors.py in __get__(self, instance, _type)
#      16             return self
#      17
# ---> 18         setattr(instance, self.__func__.__name__, self.__func__(instance))
#      19
#      20         # This descriptor is now overridden for this instance:
#
# ~/repos/integration/dscim/menu/main_recipe.py in global_consumption_pulse(self)
#    1080         gc_no_pulse = []
#    1081         for wp in self.weitzman_parameter:
# -> 1082             gc = self.weitzman_min(
#    1083                 no_cc_consumption=self.global_consumption,
#    1084                 cc_consumption=cc_cons,
#
# ~/repos/integration/dscim/menu/main_recipe.py in weitzman_min(self, no_cc_consumption, cc_consumption, parameter)
#     979
#     980         w_utility = parameter ** (1 - self.eta) / (1 - self.eta)
# --> 981         bottom_utility = parameter ** (-self.eta) * (parameter - cc_consumption)
#     982         bottom_coded_cons = power(
#     983             ((1 - self.eta) * (w_utility - bottom_utility)), (1 / (1 - self.eta))
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/_typed_ops.py in __sub__(self, other)
#     207
#     208     def __sub__(self, other):
# --> 209         return self._binary_op(other, operator.sub)
#     210
#     211     def __mul__(self, other):
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataarray.py in _binary_op(self, other, f, reflexive)
#    3079
#    3080         variable = (
# -> 3081             f(self.variable, other_variable)
#    3082             if not reflexive
#    3083             else f(other_variable, self.variable)
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/_typed_ops.py in __sub__(self, other)
#     397
#     398     def __sub__(self, other):
# --> 399         return self._binary_op(other, operator.sub)
#     400
#     401     def __mul__(self, other):
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py in _binary_op(self, other, f, reflexive)
#    2407         with np.errstate(all="ignore"):
#    2408             new_data = (
# -> 2409                 f(self_data, other_data) if not reflexive else f(other_data, self_data)
#    2410             )
#    2411         result = Variable(dims, new_data, attrs=attrs)
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py in wrapper(self, other)
#     201             return NotImplemented
#     202         else:
# --> 203             return f(self, other)
#     204
#     205     return wrapper
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py in __sub__(self, other)
#    2178     @check_if_handled_given_other
#    2179     def __sub__(self, other):
# -> 2180         return elemwise(operator.sub, self, other)
#    2181
#    2182     @check_if_handled_given_other
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py in elemwise(op, *args, **kwargs)
#    4456         blockwise_kwargs["enforce_dtype_function"] = op
#    4457         op = _enforce_dtype
# -> 4458     result = blockwise(
#    4459         op,
#    4460         expr_inds,
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/blockwise.py in blockwise(func, out_ind, name, token, dtype, adjust_chunks, new_axes, align_arrays, concatenate, meta, *args, **kwargs)
#     172
#     173     if align_arrays:
# --> 174         chunkss, arrays = unify_chunks(*args)
#     175     else:
#     176         arginds = [(a, i) for (a, i) in toolz.partition(2, args) if i is not None]
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py in unify_chunks(*args, **kwargs)
#    3684             )
#    3685             if chunks != a.chunks and all(a.chunks):
# -> 3686                 arrays.append(a.rechunk(chunks))
#    3687             else:
#    3688                 arrays.append(a)
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py in rechunk(self, chunks, threshold, block_size_limit, balance)
#    2540         from .rechunk import rechunk  # avoid circular import
#    2541
# -> 2542         return rechunk(self, chunks, threshold, block_size_limit, balance)
#    2543
#    2544     @property
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/rechunk.py in rechunk(x, chunks, threshold, block_size_limit, balance)
#     276     )
#     277     for c in steps:
# --> 278         x = _compute_rechunk(x, c)
#     279
#     280     return x
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/rechunk.py in _compute_rechunk(x, chunks)
#     604
#     605         # New block is formed by concatenation of sliced old blocks
# --> 606         if all(d == 1 for d in rec_cat_arg.shape):
#     607             x2[key] = rec_cat_arg.flat[0]
#     608         else:
#
# KeyboardInterrupt:
