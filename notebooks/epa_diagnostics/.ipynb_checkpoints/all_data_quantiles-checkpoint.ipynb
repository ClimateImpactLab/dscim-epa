# %%
import xarray as xr
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os, sys, yaml
USER = os.getenv('USER')
from dscim.menu.simple_storage import Climate
from itertools import product
from p_tqdm import p_map, p_imap, p_uimap
import gc

# %%
USA=True

# %%
if USA==True:
    results_root = "/mnt/CIL_integration/USA_SCC_rff2"
    sectors=['CAMEL_USA']
    config = f'/home/{USER}/repos/integration/configs/USA_SCC_rff.yaml'
    output = "/mnt/CIL_integration/plots/rff_diagnostics_USA/quantile_timeseries/"
else:
    results_root = "/mnt/CIL_integration/rff2"
    sectors=['CAMEL']
    config = f'/home/{USER}/repos/integration/configs/rff2_config_all_gases.yaml'
    output = "/mnt/CIL_integration/plots/rff_diagnostics/quantile_timeseries/"

masks=['unmasked']
gases = ["CO2_Fossil","CH4","N2O"]
recipes = ['adding_up','risk_aversion']
discs = ['constant','euler_ramsey']

pulse_year = 2020
results_mask = "unmasked_None"
eta_rhos = {
    2.0 :0.0,
    1.016010255: 9.149608e-05,
    1.244459066: 0.00197263997,
    1.421158116: 0.00461878399,
    1.567899395: 0.00770271076,
}

# %%
def timeseries(param_dict):
    
    print(param_dict)
    sector = param_dict['sector']
    mask = param_dict['mask']
    recipe= param_dict['recipe']
    disc=param_dict['disc']
    eta=param_dict['eta']
    rho=param_dict['rho']
    gas = param_dict['gas']
    
    # print("test")
    results = f"{results_root}/{sector}/{pulse_year}/{results_mask}"

    # # index
    # rff_ids = pd.read_csv(
    #     f"{results}/runids/{recipe}_{disc}_eta{eta}_rho{rho}_{kind}_{mask}_runids.csv"
    # ).set_index('runid').index
    
    # runid rff_sp-simulation crosswalk
    cw = xr.open_dataset('/shares/gcp/integration/rff2/rffsp_fair_sequence.nc')

    # sccs
    sccs = xr.open_dataset(
        f"{results}/{recipe}_{disc}_eta{eta}_rho{rho}_uncollapsed_sccs.nc4"
    ).sel(weitzman_parameter='0.5', gas=gas, fair_aggregation='uncollapsed', drop=True).uncollapsed_sccs.rename('SCC')
    
    # marginal damages
    damages = xr.open_zarr(
                f"{results}/{recipe}_{disc}_eta{eta}_rho{rho}_uncollapsed_marginal_damages.zarr"
            ).sel(weitzman_parameter='0.5', gas=gas, drop=True).marginal_damages

    # discount factors
    df = xr.open_zarr(f"{results}/{recipe}_{disc}_eta{eta}_rho{rho}_uncollapsed_discount_factors.zarr"
                    ).sel(weitzman_parameter='0.5', gas=gas, drop=True).discount_factor.rename('discount_factors')

    # discounted damages
    discounted_damages = (damages * df).rename('discounted_damages')

    # emissions
    if gas == "CO2_Fossil":
        g = "C"
    elif gas == "CH4":
        g = "CH4"
    elif gas == "N2O":
        g = "N2"
    emissions = xr.open_dataset("/shares/gcp/integration/rff2/climate/emissions/rff-sp_emissions_all_gases.nc").sel(gas=g, drop=True).rename(
        {'Year' : 'year',
         'simulation' : 'rff_sp'
        }).emissions.sel(rff_sp=cw.rff_sp)

    # cumulative emissions
    c_emissions=emissions.cumsum('year').rename('cumulative_emissions')
    c_emissions['year'] = emissions.year

    # gmst
    with open(config) as config_file:
        params = yaml.full_load(config_file)
        params['climate'].update({
              'gmst_fair_path' : f"/shares/gcp/integration/rff2/climate/ar6_rff_fair162_control_pulse_all_gases_2020-2030-2040-2050-2060-2070-2080_emis_conc_rf_temp_lambdaeff_ohc_emissions-driven_naturalfix_v5.03_Feb072022.nc"
        })
    gmst = Climate(**params['climate']).fair_pulse.temperature.sel(gas=gas, drop=True).rename('gmst')
    gmst_pulse = Climate(**params['climate']).fair_pulse.temperature.sel(gas=gas, drop=True).rename('gmst')
    gmst_control = Climate(**params['climate']).fair_control.temperature.sel(gas=gas, drop=True).rename('gmst')
    gmst_pulse_minus_control = gmst_pulse - gmst_control
    gmst_pulse_minus_control = gmst_pulse_minus_control.rename("gmst_pulse_minus_control")

    data = xr.combine_by_coords([i.to_dataset() for i in 
                                 [sccs, damages, df, discounted_damages, emissions, c_emissions, gmst, gmst_pulse_minus_control]])
    # import pdb; pdb.set_trace()
    
    # data = data.sel(runid=rff_ids).to_dataframe().reset_index()
    data = data.quantile(np.arange(0.05,1,0.05), dim = "runid").to_dataframe().reset_index()
    fig, ax = plt.subplots(7,1,figsize=(10,15), sharex=True)
    
    for i, yvar in enumerate(['cumulative_emissions', 'emissions', 'gmst', 'gmst_pulse_minus_control', 
                              'marginal_damages', 'discount_factors', 'discounted_damages']):

        sns.lineplot(data=data,
                 x='year',
                 y=yvar,
                 hue='quantile',
                 ax=ax[i]
                )

        ax[i].set_title(yvar)
        if i > 0:
            ax[i].get_legend().remove()
    
    plt.subplots_adjust(top=0.9)
    fig.suptitle(f"mask={mask} \n {sector} {recipe} {disc}, eta={eta} rho={rho}")
    os.makedirs(f"{output}/{sector}", exist_ok=True)
    plt.savefig(
        f'{output}/{sector}/vars_timeseries_{gas}_{sector}_{recipe}_{disc}_{eta}_{rho}_{mask}.png', 
        bbox_inches='tight', 
        dpi=300
        )
    plt.close()
    del(data)
    del(gmst_pulse_minus_control)
    del(gmst_control)
    del(gmst_pulse)
    del(gmst)
    del(c_emissions)
    del(emissions)
    del(discounted_damages)
    del(sccs)
    del(cw)
    del(damages)
    del(df)
    gc.collect(0)
    gc.collect(1)
    gc.collect(2)
    
    
    # return data

# %%
param_dict_list = list()
i=0
for s, m, er, g, r, d  in product(sectors, masks, eta_rhos.items(), gases, recipes, discs):
    print(s,m, er,g,r,d)
    # print(i)
    param_dict={}
    param_dict['sector']=s
    param_dict['mask']=m
    param_dict['eta']=er[0]
    param_dict['rho']=er[1]
    param_dict['gas']=g
    param_dict['recipe']=r
    param_dict['disc']=d
    param_dict_list.append(param_dict)
    i=i+1

p_map(timeseries, param_dict_list,num_cpus = 10)
# Out:
# CAMEL_USA unmasked (2.0, 0.0) CO2_Fossil adding_up constant
# CAMEL_USA unmasked (2.0, 0.0) CO2_Fossil adding_up euler_ramsey
# CAMEL_USA unmasked (2.0, 0.0) CO2_Fossil risk_aversion constant
# CAMEL_USA unmasked (2.0, 0.0) CO2_Fossil risk_aversion euler_ramsey
# CAMEL_USA unmasked (2.0, 0.0) CH4 adding_up constant
# CAMEL_USA unmasked (2.0, 0.0) CH4 adding_up euler_ramsey
# CAMEL_USA unmasked (2.0, 0.0) CH4 risk_aversion constant
# CAMEL_USA unmasked (2.0, 0.0) CH4 risk_aversion euler_ramsey
# CAMEL_USA unmasked (2.0, 0.0) N2O adding_up constant
# CAMEL_USA unmasked (2.0, 0.0) N2O adding_up euler_ramsey
# CAMEL_USA unmasked (2.0, 0.0) N2O risk_aversion constant
# CAMEL_USA unmasked (2.0, 0.0) N2O risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) CO2_Fossil adding_up constant
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) CO2_Fossil adding_up euler_ramsey
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) CO2_Fossil risk_aversion constant
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) CO2_Fossil risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) CH4 adding_up constant
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) CH4 adding_up euler_ramsey
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) CH4 risk_aversion constant
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) CH4 risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) N2O adding_up constant
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) N2O adding_up euler_ramsey
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) N2O risk_aversion constant
# CAMEL_USA unmasked (1.016010255, 9.149608e-05) N2O risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.244459066, 0.00197263997) CO2_Fossil adding_up constant
# CAMEL_USA unmasked (1.244459066, 0.00197263997) CO2_Fossil adding_up euler_ramsey
# CAMEL_USA unmasked (1.244459066, 0.00197263997) CO2_Fossil risk_aversion constant
# CAMEL_USA unmasked (1.244459066, 0.00197263997) CO2_Fossil risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.244459066, 0.00197263997) CH4 adding_up constant
# CAMEL_USA unmasked (1.244459066, 0.00197263997) CH4 adding_up euler_ramsey
# CAMEL_USA unmasked (1.244459066, 0.00197263997) CH4 risk_aversion constant
# CAMEL_USA unmasked (1.244459066, 0.00197263997) CH4 risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.244459066, 0.00197263997) N2O adding_up constant
# CAMEL_USA unmasked (1.244459066, 0.00197263997) N2O adding_up euler_ramsey
# CAMEL_USA unmasked (1.244459066, 0.00197263997) N2O risk_aversion constant
# CAMEL_USA unmasked (1.244459066, 0.00197263997) N2O risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.421158116, 0.00461878399) CO2_Fossil adding_up constant
# CAMEL_USA unmasked (1.421158116, 0.00461878399) CO2_Fossil adding_up euler_ramsey
# CAMEL_USA unmasked (1.421158116, 0.00461878399) CO2_Fossil risk_aversion constant
# CAMEL_USA unmasked (1.421158116, 0.00461878399) CO2_Fossil risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.421158116, 0.00461878399) CH4 adding_up constant
# CAMEL_USA unmasked (1.421158116, 0.00461878399) CH4 adding_up euler_ramsey
# CAMEL_USA unmasked (1.421158116, 0.00461878399) CH4 risk_aversion constant
# CAMEL_USA unmasked (1.421158116, 0.00461878399) CH4 risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.421158116, 0.00461878399) N2O adding_up constant
# CAMEL_USA unmasked (1.421158116, 0.00461878399) N2O adding_up euler_ramsey
# CAMEL_USA unmasked (1.421158116, 0.00461878399) N2O risk_aversion constant
# CAMEL_USA unmasked (1.421158116, 0.00461878399) N2O risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.567899395, 0.00770271076) CO2_Fossil adding_up constant
# CAMEL_USA unmasked (1.567899395, 0.00770271076) CO2_Fossil adding_up euler_ramsey
# CAMEL_USA unmasked (1.567899395, 0.00770271076) CO2_Fossil risk_aversion constant
# CAMEL_USA unmasked (1.567899395, 0.00770271076) CO2_Fossil risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.567899395, 0.00770271076) CH4 adding_up constant
# CAMEL_USA unmasked (1.567899395, 0.00770271076) CH4 adding_up euler_ramsey
# CAMEL_USA unmasked (1.567899395, 0.00770271076) CH4 risk_aversion constant
# CAMEL_USA unmasked (1.567899395, 0.00770271076) CH4 risk_aversion euler_ramsey
# CAMEL_USA unmasked (1.567899395, 0.00770271076) N2O adding_up constant
# CAMEL_USA unmasked (1.567899395, 0.00770271076) N2O adding_up euler_ramsey
# CAMEL_USA unmasked (1.567899395, 0.00770271076) N2O risk_aversion constant
# CAMEL_USA unmasked (1.567899395, 0.00770271076) N2O risk_aversion euler_ramsey
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'CO2_Fossil', 'recipe': 'adding_up', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'CO2_Fossil', 'recipe': 'risk_aversion', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'CO2_Fossil', 'recipe': 'adding_up', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'CO2_Fossil', 'recipe': 'risk_aversion', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'CH4', 'recipe': 'adding_up', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'CH4', 'recipe': 'risk_aversion', 'disc': 'constant'}{'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'CH4', 'recipe': 'adding_up', 'disc': 'euler_ramsey'}{'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'N2O', 'recipe': 'adding_up', 'disc': 'euler_ramsey'}{'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'CH4', 'recipe': 'risk_aversion', 'disc': 'euler_ramsey'}{'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'N2O', 'recipe': 'adding_up', 'disc': 'constant'}
#   0%|          | 0/60 [00:00<?, ?it/s]
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1395: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1395: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1395: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1395: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'N2O', 'recipe': 'risk_aversion', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 2.0, 'rho': 0.0, 'gas': 'N2O', 'recipe': 'risk_aversion', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'CO2_Fossil', 'recipe': 'adding_up', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'CO2_Fossil', 'recipe': 'adding_up', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'CO2_Fossil', 'recipe': 'risk_aversion', 'disc': 'constant'}
# /home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1395: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-8:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
# Traceback (most recent call last):
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_150844/3660919243.py", line 73, in timeseries
#     data = data.quantile(np.arange(0.05,1,0.05), dim = "runid").to_dataframe().reset_index()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_150844/3660919243.py", line 73, in timeseries
#     data = data.quantile(np.arange(0.05,1,0.05), dim = "runid").to_dataframe().reset_index()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5394, in to_dataframe
#     return self._to_dataframe(ordered_dims=ordered_dims)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 75, in _wrapreduction
#     reduction = getattr(obj, method)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
# AttributeError: 'int' object has no attribute 'prod'
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5394, in to_dataframe
#     return self._to_dataframe(ordered_dims=ordered_dims)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5358, in _to_dataframe
#     data = [
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5358, in _to_dataframe
#     data = [
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5359, in <listcomp>
#     self._variables[k].set_dims(ordered_dims).values.reshape(-1)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py", line 519, in values
#     return _as_array_or_item(self._data)
#   File "/tmp/ipykernel_150844/3660919243.py", line 79, in timeseries
#     sns.lineplot(data=data,
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/_decorators.py", line 46, in inner_f
#     return f(**kwargs)
#   File "/tmp/ipykernel_150844/3660919243.py", line 79, in timeseries
#     sns.lineplot(data=data,
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5359, in <listcomp>
#     self._variables[k].set_dims(ordered_dims).values.reshape(-1)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_150844/3660919243.py", line 79, in timeseries
#     sns.lineplot(data=data,
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py", line 519, in values
#     return _as_array_or_item(self._data)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py", line 259, in _as_array_or_item
#     data = np.asarray(data)
#   File "/tmp/ipykernel_150844/3660919243.py", line 79, in timeseries
#     sns.lineplot(data=data,
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py", line 1534, in __array__
#     x = self.compute()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/_decorators.py", line 46, in inner_f
#     return f(**kwargs)
#   File "/tmp/ipykernel_150844/3660919243.py", line 73, in timeseries
#     data = data.quantile(np.arange(0.05,1,0.05), dim = "runid").to_dataframe().reset_index()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py", line 259, in _as_array_or_item
#     data = np.asarray(data)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py", line 288, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5394, in to_dataframe
#     return self._to_dataframe(ordered_dims=ordered_dims)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/_decorators.py", line 46, in inner_f
#     return f(**kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 710, in lineplot
#     p.plot(ax, kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 499, in plot
#     x, y, y_ci = self.aggregate(y, x, u)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py", line 570, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 414, in aggregate
#     cis = grouped.apply(bootstrapped_cis)
#   File "/tmp/ipykernel_150844/3660919243.py", line 79, in timeseries
#     sns.lineplot(data=data,
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 710, in lineplot
#     p.plot(ax, kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/_decorators.py", line 46, in inner_f
#     return f(**kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py", line 1534, in __array__
#     x = self.compute()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 710, in lineplot
#     p.plot(ax, kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5358, in _to_dataframe
#     data = [
#   File "/tmp/ipykernel_150844/3660919243.py", line 73, in timeseries
#     data = data.quantile(np.arange(0.05,1,0.05), dim = "runid").to_dataframe().reset_index()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py", line 288, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 499, in plot
#     x, y, y_ci = self.aggregate(y, x, u)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 710, in lineplot
#     p.plot(ax, kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 414, in aggregate
#     cis = grouped.apply(bootstrapped_cis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5359, in <listcomp>
#     self._variables[k].set_dims(ordered_dims).values.reshape(-1)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py", line 570, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/generic.py", line 223, in apply
#     return super().apply(func, *args, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/_decorators.py", line 46, in inner_f
#     return f(**kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/generic.py", line 223, in apply
#     return super().apply(func, *args, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 499, in plot
#     x, y, y_ci = self.aggregate(y, x, u)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 414, in aggregate
#     cis = grouped.apply(bootstrapped_cis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/threaded.py", line 79, in get
#     results = get_async(
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5394, in to_dataframe
#     return self._to_dataframe(ordered_dims=ordered_dims)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 499, in plot
#     x, y, y_ci = self.aggregate(y, x, u)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5358, in _to_dataframe
#     data = [
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py", line 496, in get_async
#     for key, res_info, failed in queue_get(queue).result():
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/threaded.py", line 79, in get
#     results = get_async(
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py", line 496, in get_async
#     for key, res_info, failed in queue_get(queue).result():
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/generic.py", line 223, in apply
#     return super().apply(func, *args, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 710, in lineplot
#     p.plot(ax, kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py", line 134, in queue_get
#     return q.get()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 499, in plot
#     x, y, y_ci = self.aggregate(y, x, u)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/queue.py", line 170, in get
#     self.not_empty.wait()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1275, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1275, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 414, in aggregate
#     cis = grouped.apply(bootstrapped_cis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1309, in _python_apply_general
#     keys, values, mutated = self.grouper.apply(f, data, self.axis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/generic.py", line 223, in apply
#     return super().apply(func, *args, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py", line 134, in queue_get
#     return q.get()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py", line 519, in values
#     return _as_array_or_item(self._data)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1309, in _python_apply_general
#     keys, values, mutated = self.grouper.apply(f, data, self.axis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1275, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/dataset.py", line 5359, in <listcomp>
#     self._variables[k].set_dims(ordered_dims).values.reshape(-1)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/ops.py", line 852, in apply
#     res = f(group)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py", line 519, in values
#     return _as_array_or_item(self._data)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1309, in _python_apply_general
#     keys, values, mutated = self.grouper.apply(f, data, self.axis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1275, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1309, in _python_apply_general
#     keys, values, mutated = self.grouper.apply(f, data, self.axis)
# KeyboardInterrupt
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/ops.py", line 852, in apply
#     res = f(group)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py", line 259, in _as_array_or_item
#     data = np.asarray(data)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/queue.py", line 170, in get
#     self.not_empty.wait()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 395, in bootstrapped_cis
#     boots = bootstrap(vals, func=func, n_boot=n_boot, seed=seed)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/ops.py", line 852, in apply
#     res = f(group)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/ops.py", line 852, in apply
#     res = f(group)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 396, in bootstrapped_cis
#     cis = ci_func(boots, ci)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/algorithms.py", line 84, in bootstrap
#     sample = [a.take(resampler, axis=0) for a in args]
#   File "/tmp/ipykernel_150844/3660919243.py", line 79, in timeseries
#     sns.lineplot(data=data,
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 395, in bootstrapped_cis
#     boots = bootstrap(vals, func=func, n_boot=n_boot, seed=seed)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/utils.py", line 475, in ci
#     return np.nanpercentile(a, p, axis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 395, in bootstrapped_cis
#     boots = bootstrap(vals, func=func, n_boot=n_boot, seed=seed)
#   File "<__array_function__ internals>", line 5, in nanpercentile
# KeyboardInterrupt
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/algorithms.py", line 83, in bootstrap
#     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 414, in aggregate
#     cis = grouped.apply(bootstrapped_cis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/xarray/core/variable.py", line 259, in _as_array_or_item
#     data = np.asarray(data)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py", line 1534, in __array__
#     x = self.compute()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/nanfunctions.py", line 1249, in nanpercentile
#     return _nanquantile_unchecked(
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/array/core.py", line 1534, in __array__
#     x = self.compute()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/generic.py", line 223, in apply
#     return super().apply(func, *args, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/_decorators.py", line 46, in inner_f
#     return f(**kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/algorithms.py", line 84, in <listcomp>
#     sample = [a.take(resampler, axis=0) for a in args]
# KeyboardInterrupt
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py", line 288, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1275, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py", line 288, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
# KeyboardInterrupt
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1309, in _python_apply_general
#     keys, values, mutated = self.grouper.apply(f, data, self.axis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 710, in lineplot
#     p.plot(ax, kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/nanfunctions.py", line 1374, in _nanquantile_unchecked
#     r, k = function_base._ureduce(
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/algorithms.py", line 85, in bootstrap
#     boot_dist.append(f(*sample, **func_kwargs))
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/ops.py", line 852, in apply
#     res = f(group)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 395, in bootstrapped_cis
#     boots = bootstrap(vals, func=func, n_boot=n_boot, seed=seed)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/algorithms.py", line 83, in bootstrap
#     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py", line 570, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/base.py", line 570, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "_generator.pyx", line 540, in numpy.random._generator.Generator.integers
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/function_base.py", line 3564, in _ureduce
#     r = func(a, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/algorithms.py", line 66, in f
#     return getattr(x, func)()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/nanfunctions.py", line 1393, in _nanquantile_ureduce_func
#     result = _nanquantile_1d(part, q, overwrite_input, interpolation)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/threaded.py", line 79, in get
#     results = get_async(
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/nanfunctions.py", line 1418, in _nanquantile_1d
#     return function_base._quantile_unchecked(
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 499, in plot
#     x, y, y_ci = self.aggregate(y, x, u)
#   File "_bounded_integers.pyx", line 1228, in numpy.random._bounded_integers._rand_int64
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py", line 496, in get_async
#     for key, res_info, failed in queue_get(queue).result():
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/function_base.py", line 3986, in _quantile_unchecked
#     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/threaded.py", line 79, in get
#     results = get_async(
#   File "<__array_function__ internals>", line 5, in prod
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/lib/function_base.py", line 3513, in _ureduce
#     def _ureduce(a, func, **kwargs):
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/core/_methods.py", line 167, in _mean
#     rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py", line 496, in get_async
#     for key, res_info, failed in queue_get(queue).result():
# KeyboardInterrupt
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 414, in aggregate
#     cis = grouped.apply(bootstrapped_cis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py", line 134, in queue_get
#     return q.get()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/core/_methods.py", line 76, in _count_reduce_items
#     items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/queue.py", line 170, in get
#     self.not_empty.wait()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/generic.py", line 223, in apply
#     return super().apply(func, *args, **kwargs)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 3051, in prod
#     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 69, in _wrapreduction
#     def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# KeyboardInterrupt
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/dask/local.py", line 134, in queue_get
#     return q.get()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1275, in apply
#     result = self._python_apply_general(f, self._selected_obj)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/queue.py", line 170, in get
#     self.not_empty.wait()
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/groupby.py", line 1309, in _python_apply_general
#     keys, values, mutated = self.grouper.apply(f, data, self.axis)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/pandas/core/groupby/ops.py", line 852, in apply
#     res = f(group)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/threading.py", line 302, in wait
#     waiter.acquire()
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'CO2_Fossil', 'recipe': 'risk_aversion', 'disc': 'euler_ramsey'}
# KeyboardInterrupt
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'CH4', 'recipe': 'adding_up', 'disc': 'constant'}
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/relational.py", line 395, in bootstrapped_cis
#     boots = bootstrap(vals, func=func, n_boot=n_boot, seed=seed)
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/seaborn/algorithms.py", line 83, in bootstrap
#     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
#   File "_generator.pyx", line 540, in numpy.random._generator.Generator.integers
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'CH4', 'recipe': 'adding_up', 'disc': 'euler_ramsey'}
#   File "_bounded_integers.pyx", line 1228, in numpy.random._bounded_integers._rand_int64
#   File "<__array_function__ internals>", line 5, in prod
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 3051, in prod
#     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#   File "/home/liruixue/miniconda3/envs/dscim/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 75, in _wrapreduction
#     reduction = getattr(obj, method)
# KeyboardInterrupt
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'CH4', 'recipe': 'risk_aversion', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'CH4', 'recipe': 'risk_aversion', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'N2O', 'recipe': 'adding_up', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'N2O', 'recipe': 'adding_up', 'disc': 'euler_ramsey'}{'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'N2O', 'recipe': 'risk_aversion', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.016010255, 'rho': 9.149608e-05, 'gas': 'N2O', 'recipe': 'risk_aversion', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'CO2_Fossil', 'recipe': 'adding_up', 'disc': 'constant'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py in next(self, timeout)
#     850             try:
# --> 851                 item = self._items.popleft()
#     852             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_150844/6105018.py in <module>
#      15     i=i+1
#      16
# ---> 17 p_map(timeseries, param_dict_list,num_cpus = 10)
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/p_tqdm/p_tqdm.py in p_map(function, *iterables, **kwargs)
#      58     ordered = True
#      59     generator = _parallel(ordered, function, *iterables, **kwargs)
# ---> 60     result = list(generator)
#      61
#      62     return result
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/p_tqdm/p_tqdm.py in _parallel(ordered, function, *iterables, **kwargs)
#      47     map_func = getattr(pool, map_type)
#      48
# ---> 49     for item in tqdm(map_func(function, *iterables), total=length, **kwargs):
#      50         yield item
#      51
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/tqdm/notebook.py in __iter__(self)
#     255     def __iter__(self):
#     256         try:
# --> 257             for obj in super(tqdm_notebook, self).__iter__():
#     258                 # return super(tqdm...) will not catch exception
#     259                 yield obj
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/tqdm/std.py in __iter__(self)
#    1178
#    1179         try:
# -> 1180             for obj in iterable:
#    1181                 yield obj
#    1182                 # Update and possibly print the progressbar.
#
# ~/miniconda3/envs/dscim/lib/python3.8/site-packages/multiprocess/pool.py in next(self, timeout)
#     854                     self._pool = None
#     855                     raise StopIteration from None
# --> 856                 self._cond.wait(timeout)
#     857                 try:
#     858                     item = self._items.popleft()
#
# ~/miniconda3/envs/dscim/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'CO2_Fossil', 'recipe': 'adding_up', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'CO2_Fossil', 'recipe': 'risk_aversion', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'CO2_Fossil', 'recipe': 'risk_aversion', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'CH4', 'recipe': 'adding_up', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'CH4', 'recipe': 'adding_up', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'CH4', 'recipe': 'risk_aversion', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'CH4', 'recipe': 'risk_aversion', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'N2O', 'recipe': 'adding_up', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'N2O', 'recipe': 'adding_up', 'disc': 'euler_ramsey'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'N2O', 'recipe': 'risk_aversion', 'disc': 'constant'}
# {'sector': 'CAMEL_USA', 'mask': 'unmasked', 'eta': 1.244459066, 'rho': 0.00197263997, 'gas': 'N2O', 'recipe': 'risk_aversion', 'disc': 'euler_ramsey'}
